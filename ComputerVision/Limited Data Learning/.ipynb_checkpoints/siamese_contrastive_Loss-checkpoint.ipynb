# %%
##This notebook is based on https://keras.io/examples/vision/siamese_contrastive/

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Apr  5 12:27:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#mounting google drive on colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dataset=pd.read_csv('./drive/MyDrive/best_model_28_representation_train_040422.csv').iloc[:,1:]
val_dataset=pd.read_csv('./drive/MyDrive/best_model_28_representation_val_040422.csv').iloc[:,1:]

# %%
train_dataset
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.033333  0.313336  0.025133  0.229388  0.136946  0.034979  0.120104
# 1      0.093444  0.316758  0.170155  0.137241  0.259935  0.474877  0.000000
# 2      0.005281  0.349727  0.094547  0.376952  0.304110  0.114644  0.173896
# 3      0.089383  0.107351  0.075641  0.013774  0.096981  0.001354  0.072457
# 4      0.013804  0.034383  0.114037  0.031434  0.449520  0.003940  0.158426
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995  0.008469  0.153707  0.295961  0.640903  0.147320  0.107286  0.033159
# 39996  0.010601  0.295052  0.014810  0.608878  0.032543  0.013807  0.200572
# 39997  0.192546  0.433518  0.085116  0.000000  0.819737  0.000000  0.049733
# 39998  0.052466  1.688614  0.070324  0.110022  0.126059  0.000000  0.095915
# 39999  0.025741  0.752354  0.080995  0.015271  0.802826  0.000000  0.000496
#
#               7         8         9  ...      2039      2040      2041  \
# 0      0.196935  0.023299  0.166517  ...  0.561781  0.001802  0.210695
# 1      0.194750  0.067905  0.051878  ...  1.161999  0.064962  0.178196
# 2      0.426651  0.051706  0.172470  ...  0.607481  0.092371  0.017004
# 3      0.125850  0.032342  0.126957  ...  0.416517  0.064198  0.024564
# 4      0.118010  0.004489  0.047437  ...  0.264046  0.103955  0.075154
# ...         ...       ...       ...  ...       ...       ...       ...
# 39995  0.055960  0.008775  0.000215  ...  0.466908  0.157604  0.001789
# 39996  0.015779  0.207144  0.473168  ...  0.044090  0.042290  0.077591
# 39997  0.018173  0.015861  0.194425  ...  0.000000  0.004095  0.006790
# 39998  0.001023  0.010808  0.105967  ...  0.000000  0.058327  0.070632
# 39999  0.077876  0.074441  0.062494  ...  0.019828  0.070384  0.113285
#
#            2042      2043      2044      2045      2046      2047  \
# 0      0.161759  0.020894  0.524201  0.353692  0.020171  0.403670
# 1      0.366895  0.073961  0.799406  0.238650  0.013355  0.226344
# 2      0.155562  0.018352  0.468657  0.072951  0.036000  0.496107
# 3      0.143060  0.013859  0.805468  0.205996  0.024247  0.788354
# 4      0.008518  0.005747  0.603387  0.416539  0.005948  0.242247
# ...         ...       ...       ...       ...       ...       ...
# 39995  0.313070  0.021882  0.128249  0.420876  0.125631  0.086492
# 39996  0.028302  0.023190  0.081915  0.164003  0.035183  0.097715
# 39997  0.154554  0.153198  0.000000  0.522131  0.000262  0.001606
# 39998  0.421258  0.018547  0.004673  0.220298  0.007178  0.071261
# 39999  0.291323  0.541946  0.457819  0.277326  0.044750  0.076066
#
#        category_class
# 0                 338
# 1                 338
# 2                 338
# 3                 338
# 4                 338
# ...               ...
# 39995             591
# 39996             591
# 39997             591
# 39998             591
# 39999             591
#
# [40000 rows x 2049 columns]

# %%
val_dataset
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.037247  0.084723  0.067953  0.148163  0.190729  0.034427  0.010865
# 1     0.006566  0.147232  0.117783  0.476772  0.533292  0.588703  0.131454
# 2     0.210000  0.083216  0.107389  0.373491  0.139399  0.228461  0.224466
# 3     0.089227  0.028722  0.023529  0.516543  0.357591  1.165964  0.149411
# 4     0.005663  0.135440  0.112919  0.115065  0.094258  0.071284  0.024563
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.000638  0.113700  0.108743  0.090572  0.055815  0.000000  0.082937
# 9996  0.059231  0.211131  0.201713  0.032353  0.048716  0.000000  0.000000
# 9997  0.001761  1.463821  0.011850  0.032598  0.937367  0.021707  0.103139
# 9998  0.026339  0.870153  0.044403  0.028958  0.081213  0.000000  0.152911
# 9999  0.028445  0.396974  0.129699  0.304854  0.032658  0.027572  0.009164
#
#              7         8         9  ...      2039      2040      2041  \
# 0     0.190755  0.040758  0.071579  ...  0.413018  0.040352  0.029557
# 1     0.441281  0.010310  0.016984  ...  0.224854  0.045422  0.151592
# 2     0.400738  0.035322  0.065952  ...  0.340572  0.006806  0.127561
# 3     0.075871  0.022748  0.000000  ...  0.272945  0.010554  1.335347
# 4     0.129603  0.003601  0.212501  ...  0.402290  0.103481  0.176257
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995  0.025062  0.003649  0.045059  ...  0.713404  0.000000  0.009588
# 9996  0.077469  0.013222  0.060250  ...  0.411932  0.000000  0.000043
# 9997  0.006572  0.019002  0.021300  ...  0.000000  0.009892  0.071254
# 9998  0.002433  0.006991  0.132442  ...  0.021862  0.001303  0.022319
# 9999  0.000000  0.114894  0.589555  ...  0.069370  0.034535  0.012728
#
#           2042      2043      2044      2045      2046      2047  \
# 0     0.017327  0.082976  0.208654  0.213978  0.007254  0.369544
# 1     0.346858  0.000291  0.781311  0.047355  0.008029  0.237799
# 2     0.045913  0.742372  0.063517  0.105330  0.058667  0.092687
# 3     0.072965  0.002853  0.189264  0.011270  0.085637  0.058687
# 4     0.158090  0.010789  0.546413  0.319652  0.083233  0.016363
# ...        ...       ...       ...       ...       ...       ...
# 9995  0.051383  0.411699  0.089952  0.282519  0.000132  0.007038
# 9996  0.028635  0.034902  0.292674  0.112189  0.008453  0.048728
# 9997  0.661938  0.006536  0.265005  0.174313  0.000492  0.299318
# 9998  0.043793  0.260402  0.007712  0.034186  0.000000  0.067226
# 9999  0.155390  0.008744  0.136618  0.080729  0.018973  0.069819
#
#       category_class
# 0                338
# 1                338
# 2                338
# 3                338
# 4                338
# ...              ...
# 9995             591
# 9996             591
# 9997             591
# 9998             591
# 9999             591
#
# [10000 rows x 2049 columns]

# %%
from collections import Counter
len(Counter(train_dataset['category_class']))
# Out:
# 1000

# %%
import random
def make_pairs(x, y):
    """Creates a tuple containing image pairs with corresponding label.

    Arguments:
        x: List containing images, each index in this list corresponds to one image.
        y: List containing labels, each label with datatype of `int`.

    Returns:
        Tuple containing two numpy arrays as (pairs_of_samples, labels),
        where pairs_of_samples' shape is (2len(x), 2,n_features_dims) and
        labels are a binary array of shape (2len(x)).
    """

    num_classes = max(y) + 1
    digit_indices = [np.where(y == i)[0] for i in range(num_classes)]

    pairs = []
    labels = []

    for idx1 in range(len(x)):
        # add a matching example
        x1 = x[idx1]
        label1 = y[idx1]
        idx2 = random.choice(digit_indices[label1])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [1]

        # add a non-matching example
        label2 = random.randint(0, num_classes - 1)
        while label2 == label1:
            label2 = random.randint(0, num_classes - 1)

        idx2 = random.choice(digit_indices[label2])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [0]

    return np.array(pairs), np.array(labels).astype("float32")

# %%
x_train=train_dataset.iloc[:,:-1].values
y_train=train_dataset.iloc[:,-1].values
x_val=val_dataset.iloc[:,:-1].values
y_val=val_dataset.iloc[:,-1].values

# %%
y_val
# Out:
# array([338, 338, 338, ..., 591, 591, 591])

# %%
# make train pairs
pairs_train, labels_train = make_pairs(x_train, y_train)

# make validation pairs
pairs_val, labels_val = make_pairs(x_val, y_val)

# %%
x_train_1 = pairs_train[:, 0]  # x_train_1.shape is (60000, 28, 28)
x_train_2 = pairs_train[:, 1]

# %%
x_train_1.shape
# Out:
# (80000, 2048)

# %%
x_train_2.shape
# Out:
# (80000, 2048)

# %%
x_val_1 = pairs_val[:, 0]  # x_val_1.shape = (60000, 28, 28)
x_val_2 = pairs_val[:, 1]

# %%
# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    """Find the Euclidean distance between two vectors.

    Arguments:
        vects: List containing two tensors of same length.

    Returns:
        Tensor containing euclidean distance
        (as floating point value) between vectors.
    """

    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))


input = layers.Input((2048))
x = tf.keras.layers.BatchNormalization()(input)
x=layers.Dropout(0.2)(x)
x = layers.Dense(1000)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = layers.Dense(1000, activation="tanh")(x)
embedding_network = keras.Model(input, x)


input_1 = layers.Input((2048))
input_2 = layers.Input((2048))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1 = embedding_network(input_1)
tower_2 = embedding_network(input_2)

merge_layer = layers.Lambda(euclidean_distance)([tower_1, tower_2])
normal_layer = tf.keras.layers.BatchNormalization()(merge_layer)
output_layer = layers.Dense(1, activation="sigmoid")(normal_layer)
siamese = keras.Model(inputs=[input_1, input_2], outputs=output_layer)

# %%
def loss(margin=1):
    """Provides 'constrastive_loss' an enclosing scope with variable 'margin'.

  Arguments:
      margin: Integer, defines the baseline for distance for which pairs
              should be classified as dissimilar. - (default is 1).

  Returns:
      'constrastive_loss' function with data ('margin') attached.
  """

    # Contrastive loss = mean( (1-true_value) * square(prediction) +
    #                         true_value * square( max(margin-prediction, 0) ))
    def contrastive_loss(y_true, y_pred):
        """Calculates the constrastive loss.

      Arguments:
          y_true: List of labels, each label is of type float32.
          y_pred: List of predictions of same length as of y_true,
                  each label is of type float32.

      Returns:
          A tensor containing constrastive loss as floating point value.
      """

        square_pred = tf.math.square(y_pred)
        margin_square = tf.math.square(tf.math.maximum(margin - (y_pred), 0))
        return tf.math.reduce_mean(
            (1 - y_true) * square_pred + (y_true) * margin_square
        )

    return contrastive_loss

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint("./drive/MyDrive/SGD_Siamese_contrastive_after_r50.h5",
                             monitor="val_accuracy",
                             mode="max",
                             save_best_only = True,
                             verbose=1)


earlystop = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', # value being monitored for improvement
                          min_delta = 0, #Abs value and is the min change required before we stop
                          patience = 20, #Number of epochs we wait before stopping 
                          verbose = 1,
                          restore_best_weights = True) #keeps the best weigths once stopped
def scheduler(epoch, lr):
  return(0.1*(0.1 ** (epoch // 30)))

lr_scheduler=tf.keras.callbacks.LearningRateScheduler(scheduler,verbose=1)
# we put our call backs into a callback list
callbacks = [earlystop,checkpoint,lr_scheduler]

# %%
# !pip install tensorflow-addons
import tensorflow_addons as tfa
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 9.6 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
margin=1
siamese.compile(loss=loss(margin=margin), optimizer=tfa.optimizers.SGDW(learning_rate=0.1, momentum=0.9, nesterov=False,weight_decay=1e-4), metrics=["accuracy"])
siamese.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 2048)]       0           []
#
#  input_3 (InputLayer)           [(None, 2048)]       0           []
#
#  model (Functional)             (None, 1000)         3062192     ['input_2[0][0]',
#                                                                   'input_3[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['model[0][0]',
#                                                                   'model[1][0]']
#
#  batch_normalization_2 (BatchNo  (None, 1)           4           ['lambda[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 1)            2           ['batch_normalization_2[0][0]']
#
# ==================================================================================================
# Total params: 3,062,198
# Trainable params: 3,056,100
# Non-trainable params: 6,098
# __________________________________________________________________________________________________

# %%
history = siamese.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_data=([x_val_1, x_val_2], labels_val),
    batch_size=32,
    epochs=100,verbose=1,callbacks=callbacks
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.1.
# Epoch 1/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1295 - accuracy: 0.8166
# Epoch 1: val_accuracy improved from -inf to 0.85865, saving model to ./drive/MyDrive/SGD_Siamese_contrastive_after_r50.h5
# 2500/2500 [==============================] - 19s 6ms/step - loss: 0.1295 - accuracy: 0.8166 - val_loss: 0.1011 - val_accuracy: 0.8587 - lr: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.1.
# Epoch 2/100
# 2488/2500 [============================>.] - ETA: 0s - loss: 0.1180 - accuracy: 0.8355
# Epoch 2: val_accuracy improved from 0.85865 to 0.85880, saving model to ./drive/MyDrive/SGD_Siamese_contrastive_after_r50.h5
# 2500/2500 [==============================] - 11s 4ms/step - loss: 0.1181 - accuracy: 0.8354 - val_loss: 0.0990 - val_accuracy: 0.8588 - lr: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.1.
# Epoch 3/100
# 2486/2500 [============================>.] - ETA: 0s - loss: 0.1153 - accuracy: 0.8390
# Epoch 3: val_accuracy improved from 0.85880 to 0.86085, saving model to ./drive/MyDrive/SGD_Siamese_contrastive_after_r50.h5
# 2500/2500 [==============================] - 11s 4ms/step - loss: 0.1154 - accuracy: 0.8388 - val_loss: 0.1001 - val_accuracy: 0.8608 - lr: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.1.
# Epoch 4/100
# 2494/2500 [============================>.] - ETA: 0s - loss: 0.1138 - accuracy: 0.8413
# Epoch 4: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1138 - accuracy: 0.8412 - val_loss: 0.1014 - val_accuracy: 0.8587 - lr: 0.1000
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.1.
# Epoch 5/100
# 2486/2500 [============================>.] - ETA: 0s - loss: 0.1139 - accuracy: 0.8403
# Epoch 5: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1138 - accuracy: 0.8403 - val_loss: 0.1011 - val_accuracy: 0.8590 - lr: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.1.
# Epoch 6/100
# 2494/2500 [============================>.] - ETA: 0s - loss: 0.1132 - accuracy: 0.8419
# Epoch 6: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1132 - accuracy: 0.8419 - val_loss: 0.1002 - val_accuracy: 0.8576 - lr: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.1.
# Epoch 7/100
# 2487/2500 [============================>.] - ETA: 0s - loss: 0.1136 - accuracy: 0.8413
# Epoch 7: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1137 - accuracy: 0.8412 - val_loss: 0.1023 - val_accuracy: 0.8553 - lr: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.1.
# Epoch 8/100
# 2488/2500 [============================>.] - ETA: 0s - loss: 0.1140 - accuracy: 0.8399
# Epoch 8: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1140 - accuracy: 0.8399 - val_loss: 0.1022 - val_accuracy: 0.8559 - lr: 0.1000
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.1.
# Epoch 9/100
# 2489/2500 [============================>.] - ETA: 0s - loss: 0.1136 - accuracy: 0.8415
# Epoch 9: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1136 - accuracy: 0.8415 - val_loss: 0.1003 - val_accuracy: 0.8569 - lr: 0.1000
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.1.
# Epoch 10/100
# 2498/2500 [============================>.] - ETA: 0s - loss: 0.1155 - accuracy: 0.8382
# Epoch 10: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1155 - accuracy: 0.8383 - val_loss: 0.1015 - val_accuracy: 0.8562 - lr: 0.1000
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.1.
# Epoch 11/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.8392
# Epoch 11: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1142 - accuracy: 0.8392 - val_loss: 0.1028 - val_accuracy: 0.8562 - lr: 0.1000
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.1.
# Epoch 12/100
# 2493/2500 [============================>.] - ETA: 0s - loss: 0.1142 - accuracy: 0.8393
# Epoch 12: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1142 - accuracy: 0.8393 - val_loss: 0.1028 - val_accuracy: 0.8541 - lr: 0.1000
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.1.
# Epoch 13/100
# 2487/2500 [============================>.] - ETA: 0s - loss: 0.1140 - accuracy: 0.8404
# Epoch 13: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1141 - accuracy: 0.8402 - val_loss: 0.1048 - val_accuracy: 0.8511 - lr: 0.1000
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.1.
# Epoch 14/100
# 2488/2500 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.8403
# Epoch 14: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1144 - accuracy: 0.8404 - val_loss: 0.1016 - val_accuracy: 0.8570 - lr: 0.1000
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.1.
# Epoch 15/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.8399
# Epoch 15: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1139 - accuracy: 0.8399 - val_loss: 0.1035 - val_accuracy: 0.8551 - lr: 0.1000
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.1.
# Epoch 16/100
# 2496/2500 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.8415
# Epoch 16: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1135 - accuracy: 0.8416 - val_loss: 0.1004 - val_accuracy: 0.8586 - lr: 0.1000
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.1.
# Epoch 17/100
# 2492/2500 [============================>.] - ETA: 0s - loss: 0.1136 - accuracy: 0.8408
# Epoch 17: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1136 - accuracy: 0.8407 - val_loss: 0.1024 - val_accuracy: 0.8575 - lr: 0.1000
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.1.
# Epoch 18/100
# 2491/2500 [============================>.] - ETA: 0s - loss: 0.1127 - accuracy: 0.8425
# Epoch 18: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1127 - accuracy: 0.8425 - val_loss: 0.1005 - val_accuracy: 0.8591 - lr: 0.1000
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.1.
# Epoch 19/100
# 2490/2500 [============================>.] - ETA: 0s - loss: 0.1123 - accuracy: 0.8429
# Epoch 19: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1123 - accuracy: 0.8429 - val_loss: 0.1008 - val_accuracy: 0.8571 - lr: 0.1000
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.1.
# Epoch 20/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.8425
# Epoch 20: val_accuracy did not improve from 0.86085
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1123 - accuracy: 0.8425 - val_loss: 0.1015 - val_accuracy: 0.8577 - lr: 0.1000
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.1.
# Epoch 21/100
# 2486/2500 [============================>.] - ETA: 0s - loss: 0.1122 - accuracy: 0.8427
# Epoch 21: val_accuracy improved from 0.86085 to 0.86110, saving model to ./drive/MyDrive/SGD_Siamese_contrastive_after_r50.h5
# 2500/2500 [==============================] - 11s 4ms/step - loss: 0.1123 - accuracy: 0.8426 - val_loss: 0.0986 - val_accuracy: 0.8611 - lr: 0.1000
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.1.
# Epoch 22/100
# 2489/2500 [============================>.] - ETA: 0s - loss: 0.1124 - accuracy: 0.8425
# Epoch 22: val_accuracy did not improve from 0.86110
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1124 - accuracy: 0.8425 - val_loss: 0.1028 - val_accuracy: 0.8569 - lr: 0.1000
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.1.
# Epoch 23/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1113 - accuracy: 0.8442
# Epoch 23: val_accuracy did not improve from 0.86110
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1113 - accuracy: 0.8441 - val_loss: 0.1001 - val_accuracy: 0.8595 - lr: 0.1000
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.1.
# Epoch 24/100
# 2494/2500 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.8421
# Epoch 24: val_accuracy did not improve from 0.86110
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1127 - accuracy: 0.8421 - val_loss: 0.1000 - val_accuracy: 0.8572 - lr: 0.1000
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.1.
# Epoch 25/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.8430
# Epoch 25: val_accuracy improved from 0.86110 to 0.86175, saving model to ./drive/MyDrive/SGD_Siamese_contrastive_after_r50.h5
# 2500/2500 [==============================] - 11s 4ms/step - loss: 0.1120 - accuracy: 0.8430 - val_loss: 0.0989 - val_accuracy: 0.8618 - lr: 0.1000
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.1.
# Epoch 26/100
# 2489/2500 [============================>.] - ETA: 0s - loss: 0.1119 - accuracy: 0.8433
# Epoch 26: val_accuracy did not improve from 0.86175
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1118 - accuracy: 0.8433 - val_loss: 0.0999 - val_accuracy: 0.8605 - lr: 0.1000
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.1.
# Epoch 27/100
# 2492/2500 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.8445
# Epoch 27: val_accuracy improved from 0.86175 to 0.86425, saving model to ./drive/MyDrive/SGD_Siamese_contrastive_after_r50.h5
# 2500/2500 [==============================] - 11s 4ms/step - loss: 0.1115 - accuracy: 0.8445 - val_loss: 0.0975 - val_accuracy: 0.8643 - lr: 0.1000
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.1.
# Epoch 28/100
# 2489/2500 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.8429
# Epoch 28: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1120 - accuracy: 0.8429 - val_loss: 0.0990 - val_accuracy: 0.8624 - lr: 0.1000
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.1.
# Epoch 29/100
# 2487/2500 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.8459
# Epoch 29: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1114 - accuracy: 0.8460 - val_loss: 0.1000 - val_accuracy: 0.8615 - lr: 0.1000
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.1.
# Epoch 30/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1110 - accuracy: 0.8459
# Epoch 30: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1110 - accuracy: 0.8459 - val_loss: 0.1044 - val_accuracy: 0.8528 - lr: 0.1000
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 31/100
# 2496/2500 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.8575
# Epoch 31: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1032 - accuracy: 0.8575 - val_loss: 0.1002 - val_accuracy: 0.8595 - lr: 0.0100
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 32/100
# 2496/2500 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.8541
# Epoch 32: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1053 - accuracy: 0.8541 - val_loss: 0.1035 - val_accuracy: 0.8545 - lr: 0.0100
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 33/100
# 2491/2500 [============================>.] - ETA: 0s - loss: 0.1103 - accuracy: 0.8465
# Epoch 33: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1103 - accuracy: 0.8464 - val_loss: 0.1051 - val_accuracy: 0.8505 - lr: 0.0100
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 34/100
# 2495/2500 [============================>.] - ETA: 0s - loss: 0.1153 - accuracy: 0.8380
# Epoch 34: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1153 - accuracy: 0.8379 - val_loss: 0.1069 - val_accuracy: 0.8492 - lr: 0.0100
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 35/100
# 2490/2500 [============================>.] - ETA: 0s - loss: 0.1187 - accuracy: 0.8326
# Epoch 35: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1187 - accuracy: 0.8326 - val_loss: 0.1113 - val_accuracy: 0.8415 - lr: 0.0100
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 36/100
# 2493/2500 [============================>.] - ETA: 0s - loss: 0.1219 - accuracy: 0.8282
# Epoch 36: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1219 - accuracy: 0.8281 - val_loss: 0.1107 - val_accuracy: 0.8428 - lr: 0.0100
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 37/100
# 2488/2500 [============================>.] - ETA: 0s - loss: 0.1242 - accuracy: 0.8237
# Epoch 37: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1243 - accuracy: 0.8234 - val_loss: 0.1112 - val_accuracy: 0.8417 - lr: 0.0100
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 38/100
# 2494/2500 [============================>.] - ETA: 0s - loss: 0.1251 - accuracy: 0.8228
# Epoch 38: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1252 - accuracy: 0.8227 - val_loss: 0.1127 - val_accuracy: 0.8399 - lr: 0.0100
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 39/100
# 2489/2500 [============================>.] - ETA: 0s - loss: 0.1267 - accuracy: 0.8202
# Epoch 39: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1267 - accuracy: 0.8202 - val_loss: 0.1110 - val_accuracy: 0.8411 - lr: 0.0100
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 40/100
# 2490/2500 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.8204
# Epoch 40: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1267 - accuracy: 0.8203 - val_loss: 0.1118 - val_accuracy: 0.8406 - lr: 0.0100
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 41/100
# 2500/2500 [==============================] - ETA: 0s - loss: 0.1267 - accuracy: 0.8191
# Epoch 41: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1267 - accuracy: 0.8191 - val_loss: 0.1121 - val_accuracy: 0.8425 - lr: 0.0100
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 42/100
# 2492/2500 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.8170
# Epoch 42: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1280 - accuracy: 0.8170 - val_loss: 0.1113 - val_accuracy: 0.8421 - lr: 0.0100
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 43/100
# 2487/2500 [============================>.] - ETA: 0s - loss: 0.1277 - accuracy: 0.8187
# Epoch 43: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1278 - accuracy: 0.8187 - val_loss: 0.1137 - val_accuracy: 0.8386 - lr: 0.0100
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 44/100
# 2499/2500 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.8197
# Epoch 44: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1273 - accuracy: 0.8197 - val_loss: 0.1136 - val_accuracy: 0.8376 - lr: 0.0100
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 45/100
# 2497/2500 [============================>.] - ETA: 0s - loss: 0.1291 - accuracy: 0.8161
# Epoch 45: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1290 - accuracy: 0.8162 - val_loss: 0.1107 - val_accuracy: 0.8435 - lr: 0.0100
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 46/100
# 2488/2500 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.8188
# Epoch 46: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1280 - accuracy: 0.8186 - val_loss: 0.1117 - val_accuracy: 0.8425 - lr: 0.0100
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 47/100
# 2493/2500 [============================>.] - ETA: 0s - loss: 0.1277 - accuracy: 0.8175Restoring model weights from the end of the best epoch: 27.
#
# Epoch 47: val_accuracy did not improve from 0.86425
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.1276 - accuracy: 0.8175 - val_loss: 0.1128 - val_accuracy: 0.8401 - lr: 0.0100
# Epoch 47: early stopping

# %%
results = siamese.evaluate([x_val_1, x_val_2], labels_val)
print("val loss, val acc:", results)
# Out:
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0975 - accuracy: 0.8643
# val loss, val acc: [0.09754394739866257, 0.8642500042915344]

# %%
x_train_embedding=embedding_network.predict(x_train)
x_val_embedding=embedding_network.predict(x_val)

# %%
x_train_embedding.shape
# Out:
# (40000, 1000)

# %%
inputs_final = keras.Input(shape=(1000))
x = keras.layers.Dropout(0.2)(inputs_final)  # Regularize with dropout
# x=keras.layers.Dense(1000)(x)
# x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(1000,activation='softmax')(x)
model = keras.Model(inputs_final, outputs)

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 1000)]            0
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 1000)              1001000
#
# =================================================================
# Total params: 1,001,000
# Trainable params: 1,001,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint("./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5",
                             monitor="val_accuracy",
                             mode="max",
                             save_best_only = True,
                             verbose=1)


earlystop = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', # value being monitored for improvement
                          min_delta = 0, #Abs value and is the min change required before we stop
                          patience = 20, #Number of epochs we wait before stopping 
                          verbose = 1,
                          restore_best_weights = True) #keeps the best weigths once stopped
def scheduler(epoch, lr):
  return(0.1*(0.1 ** (epoch // 30)))

lr_scheduler=tf.keras.callbacks.LearningRateScheduler(scheduler,verbose=1)
# we put our call backs into a callback list
callbacks = [earlystop,checkpoint,lr_scheduler]

# %%
model.compile(optimizer= tfa.optimizers.SGDW(learning_rate=0.1, momentum=0.9, nesterov=False,weight_decay=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#onehotencoding
y_train1=np.eye(1000)[y_train]
y_val1=np.eye(1000)[y_val]

# %%
history1 = model.fit(x_train_embedding,
    y_train1,
    validation_data=(x_val_embedding, y_val1),
    batch_size=32,
    epochs=100,verbose=1,callbacks=callbacks
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.1.
# Epoch 1/100
# 1231/1250 [============================>.] - ETA: 0s - loss: 4.3913 - accuracy: 0.1676
# Epoch 1: val_accuracy improved from -inf to 0.24160, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 4s 3ms/step - loss: 4.3837 - accuracy: 0.1681 - val_loss: 3.7309 - val_accuracy: 0.2416 - lr: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.1.
# Epoch 2/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.7514 - accuracy: 0.2469
# Epoch 2: val_accuracy improved from 0.24160 to 0.25370, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 4s 4ms/step - loss: 3.7514 - accuracy: 0.2469 - val_loss: 3.7325 - val_accuracy: 0.2537 - lr: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.1.
# Epoch 3/100
# 1238/1250 [============================>.] - ETA: 0s - loss: 3.6469 - accuracy: 0.2671
# Epoch 3: val_accuracy improved from 0.25370 to 0.27050, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 5s 4ms/step - loss: 3.6470 - accuracy: 0.2672 - val_loss: 3.6317 - val_accuracy: 0.2705 - lr: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.1.
# Epoch 4/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 3.5999 - accuracy: 0.2787
# Epoch 4: val_accuracy improved from 0.27050 to 0.27570, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.6012 - accuracy: 0.2785 - val_loss: 3.6118 - val_accuracy: 0.2757 - lr: 0.1000
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.1.
# Epoch 5/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 3.5617 - accuracy: 0.2844
# Epoch 5: val_accuracy did not improve from 0.27570
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.5633 - accuracy: 0.2842 - val_loss: 3.6291 - val_accuracy: 0.2645 - lr: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.1.
# Epoch 6/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.5521 - accuracy: 0.2873
# Epoch 6: val_accuracy improved from 0.27570 to 0.28210, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.5522 - accuracy: 0.2873 - val_loss: 3.5893 - val_accuracy: 0.2821 - lr: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.1.
# Epoch 7/100
# 1229/1250 [============================>.] - ETA: 0s - loss: 3.5113 - accuracy: 0.2911
# Epoch 7: val_accuracy did not improve from 0.28210
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.5108 - accuracy: 0.2912 - val_loss: 3.6064 - val_accuracy: 0.2788 - lr: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.1.
# Epoch 8/100
# 1230/1250 [============================>.] - ETA: 0s - loss: 3.4984 - accuracy: 0.2952
# Epoch 8: val_accuracy did not improve from 0.28210
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.5005 - accuracy: 0.2949 - val_loss: 3.6296 - val_accuracy: 0.2819 - lr: 0.1000
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.1.
# Epoch 9/100
# 1229/1250 [============================>.] - ETA: 0s - loss: 3.4887 - accuracy: 0.2967
# Epoch 9: val_accuracy improved from 0.28210 to 0.28560, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.4875 - accuracy: 0.2969 - val_loss: 3.6071 - val_accuracy: 0.2856 - lr: 0.1000
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.1.
# Epoch 10/100
# 1232/1250 [============================>.] - ETA: 0s - loss: 3.4853 - accuracy: 0.2974
# Epoch 10: val_accuracy did not improve from 0.28560
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4910 - accuracy: 0.2970 - val_loss: 3.6106 - val_accuracy: 0.2797 - lr: 0.1000
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.1.
# Epoch 11/100
# 1228/1250 [============================>.] - ETA: 0s - loss: 3.4689 - accuracy: 0.3020
# Epoch 11: val_accuracy improved from 0.28560 to 0.28670, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.4736 - accuracy: 0.3018 - val_loss: 3.6015 - val_accuracy: 0.2867 - lr: 0.1000
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.1.
# Epoch 12/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 3.4671 - accuracy: 0.2992
# Epoch 12: val_accuracy did not improve from 0.28670
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4689 - accuracy: 0.2988 - val_loss: 3.6300 - val_accuracy: 0.2763 - lr: 0.1000
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.1.
# Epoch 13/100
# 1227/1250 [============================>.] - ETA: 0s - loss: 3.4563 - accuracy: 0.2987
# Epoch 13: val_accuracy did not improve from 0.28670
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4622 - accuracy: 0.2980 - val_loss: 3.6333 - val_accuracy: 0.2806 - lr: 0.1000
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.1.
# Epoch 14/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 3.4584 - accuracy: 0.3010
# Epoch 14: val_accuracy did not improve from 0.28670
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4591 - accuracy: 0.3011 - val_loss: 3.6490 - val_accuracy: 0.2835 - lr: 0.1000
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.1.
# Epoch 15/100
# 1235/1250 [============================>.] - ETA: 0s - loss: 3.4709 - accuracy: 0.3003
# Epoch 15: val_accuracy did not improve from 0.28670
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4733 - accuracy: 0.2998 - val_loss: 3.6195 - val_accuracy: 0.2856 - lr: 0.1000
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.1.
# Epoch 16/100
# 1231/1250 [============================>.] - ETA: 0s - loss: 3.4503 - accuracy: 0.2995
# Epoch 16: val_accuracy improved from 0.28670 to 0.28910, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.4521 - accuracy: 0.2995 - val_loss: 3.6004 - val_accuracy: 0.2891 - lr: 0.1000
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.1.
# Epoch 17/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 3.4613 - accuracy: 0.3005
# Epoch 17: val_accuracy did not improve from 0.28910
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4610 - accuracy: 0.3005 - val_loss: 3.5930 - val_accuracy: 0.2847 - lr: 0.1000
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.1.
# Epoch 18/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 3.4554 - accuracy: 0.3000
# Epoch 18: val_accuracy did not improve from 0.28910
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4576 - accuracy: 0.2998 - val_loss: 3.6168 - val_accuracy: 0.2838 - lr: 0.1000
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.1.
# Epoch 19/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.4588 - accuracy: 0.3000
# Epoch 19: val_accuracy did not improve from 0.28910
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4596 - accuracy: 0.2998 - val_loss: 3.6079 - val_accuracy: 0.2782 - lr: 0.1000
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.1.
# Epoch 20/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 3.4510 - accuracy: 0.3003
# Epoch 20: val_accuracy did not improve from 0.28910
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4510 - accuracy: 0.3002 - val_loss: 3.5890 - val_accuracy: 0.2883 - lr: 0.1000
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.1.
# Epoch 21/100
# 1232/1250 [============================>.] - ETA: 0s - loss: 3.4663 - accuracy: 0.2976
# Epoch 21: val_accuracy did not improve from 0.28910
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4667 - accuracy: 0.2979 - val_loss: 3.6274 - val_accuracy: 0.2883 - lr: 0.1000
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.1.
# Epoch 22/100
# 1233/1250 [============================>.] - ETA: 0s - loss: 3.4508 - accuracy: 0.3013
# Epoch 22: val_accuracy improved from 0.28910 to 0.29000, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 4s 3ms/step - loss: 3.4552 - accuracy: 0.3007 - val_loss: 3.5543 - val_accuracy: 0.2900 - lr: 0.1000
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.1.
# Epoch 23/100
# 1229/1250 [============================>.] - ETA: 0s - loss: 3.4550 - accuracy: 0.3003
# Epoch 23: val_accuracy improved from 0.29000 to 0.29280, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4598 - accuracy: 0.3000 - val_loss: 3.5554 - val_accuracy: 0.2928 - lr: 0.1000
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.1.
# Epoch 24/100
# 1228/1250 [============================>.] - ETA: 0s - loss: 3.4500 - accuracy: 0.3020
# Epoch 24: val_accuracy did not improve from 0.29280
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4533 - accuracy: 0.3018 - val_loss: 3.5405 - val_accuracy: 0.2891 - lr: 0.1000
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.1.
# Epoch 25/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 3.4398 - accuracy: 0.3019
# Epoch 25: val_accuracy did not improve from 0.29280
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4399 - accuracy: 0.3018 - val_loss: 3.6146 - val_accuracy: 0.2883 - lr: 0.1000
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.1.
# Epoch 26/100
# 1227/1250 [============================>.] - ETA: 0s - loss: 3.4483 - accuracy: 0.3027
# Epoch 26: val_accuracy did not improve from 0.29280
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4519 - accuracy: 0.3026 - val_loss: 3.6224 - val_accuracy: 0.2790 - lr: 0.1000
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.1.
# Epoch 27/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 3.4526 - accuracy: 0.3040
# Epoch 27: val_accuracy did not improve from 0.29280
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4525 - accuracy: 0.3040 - val_loss: 3.6406 - val_accuracy: 0.2845 - lr: 0.1000
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.1.
# Epoch 28/100
# 1228/1250 [============================>.] - ETA: 0s - loss: 3.4293 - accuracy: 0.3046
# Epoch 28: val_accuracy did not improve from 0.29280
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4350 - accuracy: 0.3043 - val_loss: 3.5620 - val_accuracy: 0.2875 - lr: 0.1000
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.1.
# Epoch 29/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 3.4441 - accuracy: 0.2994
# Epoch 29: val_accuracy did not improve from 0.29280
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4446 - accuracy: 0.2995 - val_loss: 3.5932 - val_accuracy: 0.2809 - lr: 0.1000
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.1.
# Epoch 30/100
# 1227/1250 [============================>.] - ETA: 0s - loss: 3.4335 - accuracy: 0.3020
# Epoch 30: val_accuracy did not improve from 0.29280
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.4362 - accuracy: 0.3018 - val_loss: 3.6069 - val_accuracy: 0.2792 - lr: 0.1000
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 31/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 2.5537 - accuracy: 0.4150
# Epoch 31: val_accuracy improved from 0.29280 to 0.37590, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.5534 - accuracy: 0.4150 - val_loss: 2.7888 - val_accuracy: 0.3759 - lr: 0.0100
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 32/100
# 1232/1250 [============================>.] - ETA: 0s - loss: 2.3938 - accuracy: 0.4387
# Epoch 32: val_accuracy improved from 0.37590 to 0.38160, saving model to ./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.3950 - accuracy: 0.4387 - val_loss: 2.7451 - val_accuracy: 0.3816 - lr: 0.0100
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 33/100
# 1227/1250 [============================>.] - ETA: 0s - loss: 2.4148 - accuracy: 0.4425
# Epoch 33: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.4160 - accuracy: 0.4421 - val_loss: 2.7468 - val_accuracy: 0.3806 - lr: 0.0100
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 34/100
# 1228/1250 [============================>.] - ETA: 0s - loss: 2.4500 - accuracy: 0.4428
# Epoch 34: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.4522 - accuracy: 0.4428 - val_loss: 2.7762 - val_accuracy: 0.3788 - lr: 0.0100
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 35/100
# 1234/1250 [============================>.] - ETA: 0s - loss: 2.5115 - accuracy: 0.4385
# Epoch 35: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.5118 - accuracy: 0.4385 - val_loss: 2.8071 - val_accuracy: 0.3792 - lr: 0.0100
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 36/100
# 1232/1250 [============================>.] - ETA: 0s - loss: 2.5605 - accuracy: 0.4345
# Epoch 36: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.5616 - accuracy: 0.4341 - val_loss: 2.8344 - val_accuracy: 0.3726 - lr: 0.0100
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 37/100
# 1236/1250 [============================>.] - ETA: 0s - loss: 2.6040 - accuracy: 0.4311
# Epoch 37: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.6042 - accuracy: 0.4310 - val_loss: 2.8612 - val_accuracy: 0.3720 - lr: 0.0100
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 38/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 2.6442 - accuracy: 0.4247
# Epoch 38: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.6447 - accuracy: 0.4245 - val_loss: 2.8771 - val_accuracy: 0.3728 - lr: 0.0100
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 39/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 2.6784 - accuracy: 0.4226
# Epoch 39: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.6796 - accuracy: 0.4226 - val_loss: 2.8986 - val_accuracy: 0.3677 - lr: 0.0100
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 40/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 2.7064 - accuracy: 0.4201
# Epoch 40: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.7066 - accuracy: 0.4200 - val_loss: 2.9144 - val_accuracy: 0.3681 - lr: 0.0100
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 41/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 2.7304 - accuracy: 0.4153
# Epoch 41: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.7310 - accuracy: 0.4151 - val_loss: 2.9236 - val_accuracy: 0.3690 - lr: 0.0100
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 42/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 2.7515 - accuracy: 0.4113
# Epoch 42: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.7507 - accuracy: 0.4117 - val_loss: 2.9327 - val_accuracy: 0.3626 - lr: 0.0100
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 43/100
# 1231/1250 [============================>.] - ETA: 0s - loss: 2.7668 - accuracy: 0.4078
# Epoch 43: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.7696 - accuracy: 0.4073 - val_loss: 2.9416 - val_accuracy: 0.3614 - lr: 0.0100
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 44/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 2.7788 - accuracy: 0.4068
# Epoch 44: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.7786 - accuracy: 0.4069 - val_loss: 2.9487 - val_accuracy: 0.3592 - lr: 0.0100
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 45/100
# 1227/1250 [============================>.] - ETA: 0s - loss: 2.7903 - accuracy: 0.4047
# Epoch 45: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.7910 - accuracy: 0.4042 - val_loss: 2.9511 - val_accuracy: 0.3592 - lr: 0.0100
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 46/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 2.8043 - accuracy: 0.4016
# Epoch 46: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.8041 - accuracy: 0.4017 - val_loss: 2.9514 - val_accuracy: 0.3570 - lr: 0.0100
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 47/100
# 1235/1250 [============================>.] - ETA: 0s - loss: 2.8113 - accuracy: 0.4007
# Epoch 47: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.8130 - accuracy: 0.4003 - val_loss: 2.9586 - val_accuracy: 0.3626 - lr: 0.0100
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 48/100
# 1228/1250 [============================>.] - ETA: 0s - loss: 2.8147 - accuracy: 0.3980
# Epoch 48: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.8154 - accuracy: 0.3975 - val_loss: 2.9616 - val_accuracy: 0.3600 - lr: 0.0100
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 49/100
# 1227/1250 [============================>.] - ETA: 0s - loss: 2.8259 - accuracy: 0.3963
# Epoch 49: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.8274 - accuracy: 0.3960 - val_loss: 2.9616 - val_accuracy: 0.3630 - lr: 0.0100
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 50/100
# 1234/1250 [============================>.] - ETA: 0s - loss: 2.8285 - accuracy: 0.3943
# Epoch 50: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.8293 - accuracy: 0.3942 - val_loss: 2.9674 - val_accuracy: 0.3572 - lr: 0.0100
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 51/100
# 1227/1250 [============================>.] - ETA: 0s - loss: 2.8295 - accuracy: 0.3948
# Epoch 51: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.8327 - accuracy: 0.3942 - val_loss: 2.9681 - val_accuracy: 0.3575 - lr: 0.0100
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.010000000000000002.
# Epoch 52/100
# 1237/1250 [============================>.] - ETA: 0s - loss: 2.8372 - accuracy: 0.3943Restoring model weights from the end of the best epoch: 32.
#
# Epoch 52: val_accuracy did not improve from 0.38160
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.8382 - accuracy: 0.3936 - val_loss: 2.9696 - val_accuracy: 0.3576 - lr: 0.0100
# Epoch 52: early stopping

# %%
model.evaluate(x_val_embedding,y_val1)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.7451 - accuracy: 0.3816
# [2.745126247406006, 0.3815999925136566]

# %%
def display_learning_curves(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    ax1.plot(history.history["loss"])
    ax1.plot(history.history["val_loss"])
    ax1.legend(["train", "valid"], loc="upper right")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2.plot(history.history["accuracy"])
    ax2.plot(history.history["val_accuracy"])
    ax2.legend(["train", "valid"], loc="upper right")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    plt.show()

# %%
display_learning_curves(history)

# %%
display_learning_curves(history1)

# %%
embedding_network.save('./drive/MyDrive/SGD_Siamese_contrastive_embeddings.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
temp1=tf.keras.models.load_model('./drive/MyDrive/SGD_Siamese_contrastive_embeddings.h5')
temp2=tf.keras.models.load_model('./drive/MyDrive/SGD_siamese_contrastive_embeddings_transferLearning2.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
temp2.evaluate(temp1.predict(x_val),y_val1)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.7451 - accuracy: 0.3816
# [2.745126485824585, 0.3815999925136566]

# %%
test_dataset=pd.read_csv('./drive/MyDrive/test_representation.csv')

# %%
test_dataset
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.000000  0.000000  0.029340  0.959396  0.032180  0.007271  0.505135
# 1      0.018695  0.131584  0.000580  0.265691  0.075151  0.005068  0.164080
# 2      0.008372  0.236403  0.014399  0.041888  0.024327  0.042268  0.086519
# 3      0.169781  0.011046  0.054933  1.199504  0.027333  0.123167  0.185943
# 4      0.050206  0.857661  0.150167  0.052228  0.291346  0.206538  0.145282
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995  0.002047  0.012996  0.043287  0.194361  0.340890  0.095029  0.137551
# 49996  0.028609  0.000027  0.154415  1.012217  0.000856  0.078721  0.403259
# 49997  0.031759  0.009449  0.047738  0.047382  0.949164  0.059264  0.016978
# 49998  0.008271  0.562913  0.022252  0.110028  0.601711  0.062303  0.476841
# 49999  0.001101  0.023040  0.043784  0.014679  0.292485  0.303807  0.093233
#
#               7         8         9  ...      2039      2040      2041  \
# 0      0.047305  0.046234  0.000000  ...  0.160508  0.108298  0.000000
# 1      0.603745  0.167325  0.076654  ...  0.029152  0.214970  0.000000
# 2      0.659389  0.053838  0.071150  ...  0.135679  0.000000  0.235405
# 3      0.762185  0.053278  0.096448  ...  0.148584  0.007761  0.816408
# 4      0.104864  0.128827  0.380020  ...  0.163841  0.060867  0.049904
# ...         ...       ...       ...  ...       ...       ...       ...
# 49995  0.295975  0.000093  0.009103  ...  0.101937  0.010900  0.057891
# 49996  0.151994  0.003251  0.013472  ...  0.033227  0.268508  0.017099
# 49997  0.000756  0.020112  0.000000  ...  0.354629  0.000000  0.229080
# 49998  0.167790  0.086034  0.083120  ...  0.269349  0.010813  0.312314
# 49999  0.168107  0.040244  0.089973  ...  0.156524  0.038731  0.110496
#
#            2042      2043      2044      2045      2046      2047  \
# 0      0.031925  0.008031  0.129452  0.450996  0.004531  0.008310
# 1      0.043662  0.057358  0.093535  0.103441  0.011182  0.052681
# 2      0.324949  0.021558  0.093964  0.012577  0.001841  0.246740
# 3      0.135283  0.010906  0.306520  1.403771  0.235088  0.000832
# 4      0.576424  0.294275  0.000000  0.080127  0.016386  0.423166
# ...         ...       ...       ...       ...       ...       ...
# 49995  0.205408  0.010592  1.026036  0.037057  0.005353  1.050666
# 49996  0.000700  0.121087  0.025590  1.007298  0.013507  0.169299
# 49997  0.020603  0.000000  0.809951  0.017986  0.058925  0.459367
# 49998  0.175110  0.289860  0.014819  0.304625  0.050381  0.012309
# 49999  0.076927  0.020674  0.203182  0.361507  0.031252  0.029597
#
#        category_class
# 0                65.0
# 1               970.0
# 2               230.0
# 3               809.0
# 4               516.0
# ...               ...
# 49995           283.0
# 49996            26.0
# 49997           232.0
# 49998           982.0
# 49999           355.0
#
# [50000 rows x 2049 columns]

# %%
x_test=test_dataset.iloc[:,:-1].values
y_test=test_dataset.iloc[:,-1].values

# %%
y_test=y_test.astype(int)

# %%
y_test1=np.eye(1000)[y_test]

# %%
temp2.evaluate(temp1.predict(x_test),y_test1)
# Out:
# 1563/1563 [==============================] - 5s 3ms/step - loss: 4.0578 - accuracy: 0.2229
# [4.057819366455078, 0.22285999357700348]
